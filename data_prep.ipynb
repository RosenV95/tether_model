# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
usdt_df=pd.read_csv("usdt_mc.csv")

# %%
btc_df=pd.read_csv("extracted_data.csv")

# %%
btc_df
# Out:
#              Date      Open      High       Low     Close  Adj Close  \
# 0     Feb 04 2022  37234.06  38121.74  37093.63  37971.30   37971.30
# 1     Feb 03 2022  36944.80  37154.60  36375.54  37154.60   37154.60
# 2     Feb 02 2022  38743.71  38834.62  36832.73  36952.98   36952.98
# 3     Feb 01 2022  38481.77  39115.13  38113.66  38743.27   38743.27
# 4     Jan 31 2022  37920.28  38647.26  36733.57  38483.13   38483.13
# ...           ...       ...       ...       ...       ...        ...
# 2595  Dec 28 2014    316.16    320.03    311.08    317.24     317.24
# 2596  Dec 27 2014    327.58    328.91    312.63    315.86     315.86
# 2597  Dec 26 2014    319.15    331.42    316.63    327.92     327.92
# 2598  Dec 25 2014    322.29    322.67    316.96    319.01     319.01
# 2599  Dec 24 2014    334.39    334.74    321.36    322.53     322.53
#
#            Volume
# 0     20855050240
# 1     18591534769
# 2     19155189416
# 3     20288500328
# 4     20734730465
# ...           ...
# ...

# %%
usdt_df.drop(['total_volumes__001', 'stats__001'], axis=1, inplace=True)

# %%
usdt_df['date'] = pd.date_range(end='02/04/2022', periods=len(usdt_df), freq='D')

# %%
usdt_df
# Out:
#         stats__002  total_volumes__002       date
# 0     3.044760e+05        5.000000e+00 2015-03-19
# 1     1.440460e+05        2.000000e+00 2015-03-20
# 2     2.516000e+05        5.000000e+01 2015-03-21
# 3     2.516000e+05        5.819600e+04 2015-03-22
# 4     2.516000e+05        3.100000e+01 2015-03-23
# ...            ...                 ...        ...
# 2510  7.806278e+10        3.788007e+10 2022-01-31
# 2511  7.801694e+10        3.673893e+10 2022-02-01
# 2512  7.803808e+10        3.806475e+10 2022-02-02
# 2513  7.806401e+10        3.677610e+10 2022-02-03
# 2514  7.806106e+10                 NaN 2022-02-04
#
# [2515 rows x 3 columns]

# %%
usdt_df.drop(usdt_df.head(100).index, inplace=True)

# %%
usdt_df.drop(usdt_df.tail(1).index, inplace=True)

# %%
usdt_df
# Out:
#         stats__002  total_volumes__002       date
# 100   4.516000e+05        1.360100e+04 2015-06-27
# 101   4.516000e+05        1.353000e+03 2015-06-28
# 102   4.516000e+05        2.400650e+05 2015-06-29
# 103   4.516000e+05        2.261860e+05 2015-06-30
# 104   4.516000e+05        7.802000e+03 2015-07-01
# ...            ...                 ...        ...
# 2509  7.819838e+10        3.030926e+10 2022-01-30
# 2510  7.806278e+10        3.788007e+10 2022-01-31
# 2511  7.801694e+10        3.673893e+10 2022-02-01
# 2512  7.803808e+10        3.806475e+10 2022-02-02
# 2513  7.806401e+10        3.677610e+10 2022-02-03
#
# [2414 rows x 3 columns]

# %%
usdt_df['stats__002']=usdt_df['stats__002'].astype('int64')

# %%
usdt_df
# Out:
#        stats__002  total_volumes__002       date
# 100        451600        1.360100e+04 2015-06-27
# 101        451600        1.353000e+03 2015-06-28
# 102        451600        2.400650e+05 2015-06-29
# 103        451600        2.261860e+05 2015-06-30
# 104        451600        7.802000e+03 2015-07-01
# ...           ...                 ...        ...
# 2509  78198382292        3.030926e+10 2022-01-30
# 2510  78062781790        3.788007e+10 2022-01-31
# 2511  78016936424        3.673893e+10 2022-02-01
# 2512  78038075903        3.806475e+10 2022-02-02
# 2513  78064010105        3.677610e+10 2022-02-03
#
# [2414 rows x 3 columns]

# %%
usdt_df['total_volumes__002']=usdt_df['total_volumes__002'].astype('int64')

# %%
usdt_df
# Out:
#        stats__002  total_volumes__002       date
# 100        451600               13601 2015-06-27
# 101        451600                1353 2015-06-28
# 102        451600              240065 2015-06-29
# 103        451600              226186 2015-06-30
# 104        451600                7802 2015-07-01
# ...           ...                 ...        ...
# 2509  78198382292         30309259657 2022-01-30
# 2510  78062781790         37880065303 2022-01-31
# 2511  78016936424         36738926224 2022-02-01
# 2512  78038075903         38064751930 2022-02-02
# 2513  78064010105         36776101831 2022-02-03
#
# [2414 rows x 3 columns]

# %%
btc_df
# Out:
#              Date      Open      High       Low     Close  Adj Close  \
# 0     Feb 04 2022  37234.06  38121.74  37093.63  37971.30   37971.30
# 1     Feb 03 2022  36944.80  37154.60  36375.54  37154.60   37154.60
# 2     Feb 02 2022  38743.71  38834.62  36832.73  36952.98   36952.98
# 3     Feb 01 2022  38481.77  39115.13  38113.66  38743.27   38743.27
# 4     Jan 31 2022  37920.28  38647.26  36733.57  38483.13   38483.13
# ...           ...       ...       ...       ...       ...        ...
# 2595  Dec 28 2014    316.16    320.03    311.08    317.24     317.24
# 2596  Dec 27 2014    327.58    328.91    312.63    315.86     315.86
# 2597  Dec 26 2014    319.15    331.42    316.63    327.92     327.92
# 2598  Dec 25 2014    322.29    322.67    316.96    319.01     319.01
# 2599  Dec 24 2014    334.39    334.74    321.36    322.53     322.53
#
#            Volume
# 0     20855050240
# 1     18591534769
# 2     19155189416
# 3     20288500328
# 4     20734730465
# ...           ...
# ...

# %%
btc_df=btc_df.iloc[::-1]

# %%
btc_df.drop(btc_df.tail(1).index, inplace=True)
# Out:
# C:\Users\Valkov\AppData\Local\Temp\ipykernel_16072\3918931986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   btc_df.drop(btc_df.tail(1).index, inplace=True)

# %%
btc_df
# Out:
#              Date      Open      High       Low     Close  Adj Close  \
# 2599  Dec 24 2014    334.39    334.74    321.36    322.53     322.53
# 2598  Dec 25 2014    322.29    322.67    316.96    319.01     319.01
# 2597  Dec 26 2014    319.15    331.42    316.63    327.92     327.92
# 2596  Dec 27 2014    327.58    328.91    312.63    315.86     315.86
# 2595  Dec 28 2014    316.16    320.03    311.08    317.24     317.24
# ...           ...       ...       ...       ...       ...        ...
# 5     Jan 30 2022  38151.92  38266.34  37437.71  37917.60   37917.60
# 4     Jan 31 2022  37920.28  38647.26  36733.57  38483.13   38483.13
# 3     Feb 01 2022  38481.77  39115.13  38113.66  38743.27   38743.27
# 2     Feb 02 2022  38743.71  38834.62  36832.73  36952.98   36952.98
# 1     Feb 03 2022  36944.80  37154.60  36375.54  37154.60   37154.60
#
#            Volume
# 2599     15092300
# 2598      9883640
# 2597     16410500
# 2596     15185200
# 2595     11676600
# ...           ...
# ...

# %%
usdt_df
# Out:
#        stats__002  total_volumes__002       date
# 100        451600               13601 2015-06-27
# 101        451600                1353 2015-06-28
# 102        451600              240065 2015-06-29
# 103        451600              226186 2015-06-30
# 104        451600                7802 2015-07-01
# ...           ...                 ...        ...
# 2509  78198382292         30309259657 2022-01-30
# 2510  78062781790         37880065303 2022-01-31
# 2511  78016936424         36738926224 2022-02-01
# 2512  78038075903         38064751930 2022-02-02
# 2513  78064010105         36776101831 2022-02-03
#
# [2414 rows x 3 columns]

# %%
btc_df
# Out:
#              Date      Open      High       Low     Close  Adj Close  \
# 2599  Dec 24 2014    334.39    334.74    321.36    322.53     322.53
# 2598  Dec 25 2014    322.29    322.67    316.96    319.01     319.01
# 2597  Dec 26 2014    319.15    331.42    316.63    327.92     327.92
# 2596  Dec 27 2014    327.58    328.91    312.63    315.86     315.86
# 2595  Dec 28 2014    316.16    320.03    311.08    317.24     317.24
# ...           ...       ...       ...       ...       ...        ...
# 5     Jan 30 2022  38151.92  38266.34  37437.71  37917.60   37917.60
# 4     Jan 31 2022  37920.28  38647.26  36733.57  38483.13   38483.13
# 3     Feb 01 2022  38481.77  39115.13  38113.66  38743.27   38743.27
# 2     Feb 02 2022  38743.71  38834.62  36832.73  36952.98   36952.98
# 1     Feb 03 2022  36944.80  37154.60  36375.54  37154.60   37154.60
#
#            Volume
# 2599     15092300
# 2598      9883640
# 2597     16410500
# 2596     15185200
# 2595     11676600
# ...           ...
# ...

# %%
btc_df['Date'] = pd.to_datetime(btc_df['Date'])
# Out:
# C:\Users\Valkov\AppData\Local\Temp\ipykernel_16072\2108826159.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   btc_df['Date'] = pd.to_datetime(btc_df['Date'])

# %%
btc_df
# Out:
#            Date      Open      High       Low     Close  Adj Close  \
# 2599 2014-12-24    334.39    334.74    321.36    322.53     322.53
# 2598 2014-12-25    322.29    322.67    316.96    319.01     319.01
# 2597 2014-12-26    319.15    331.42    316.63    327.92     327.92
# 2596 2014-12-27    327.58    328.91    312.63    315.86     315.86
# 2595 2014-12-28    316.16    320.03    311.08    317.24     317.24
# ...         ...       ...       ...       ...       ...        ...
# 5    2022-01-30  38151.92  38266.34  37437.71  37917.60   37917.60
# 4    2022-01-31  37920.28  38647.26  36733.57  38483.13   38483.13
# 3    2022-02-01  38481.77  39115.13  38113.66  38743.27   38743.27
# 2    2022-02-02  38743.71  38834.62  36832.73  36952.98   36952.98
# 1    2022-02-03  36944.80  37154.60  36375.54  37154.60   37154.60
#
#            Volume
# 2599     15092300
# 2598      9883640
# 2597     16410500
# 2596     15185200
# 2595     11676600
# ...           ...
# 5     14643548444
# ...

# %%
merged_df=pd.merge(btc_df, usdt_df, left_on='Date',right_on='date')

# %%
merged_df.rename(columns={'stats__002': 'USDT Marketcap', 'total_volumes__002': 'USDT Volume'}, inplace=True)

# %%
merged_df.drop(['date'],axis=1, inplace=True)

# %%
plt.plot(merged_df['stats__002'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\tether_model\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\envs\tether_model\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\tether_model\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'stats__002'
#
# The above exception was the direct cause of the following exception:
#
# ...
